# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanu9400/DSA_with_python/blob/main/leetcode_questions_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List

class Solution:
    def rob(self, nums: List[int]) -> int:
        if not nums:
            return 0
        if len(nums) == 1:
            return nums[0]

        prev2 = nums[0]
        prev1 = max(nums[0], nums[1])

        for i in range(2, len(nums)):
            current = max(prev1, nums[i] + prev2)
            prev2 = prev1
            prev1 = current

        return prev1

def main():

  sol = Solution()
  print(sol.rob([1, 2, 3, 1]))
  print(sol.rob([2, 7, 9, 3, 1]))

if __name__ =="__main__":
  main()
# Out:
# 4
# 12

# %%
from typing import List

class Solution:
    def maxSubArray(self, nums: List[int]) -> int:
        current_sum = max_sum = nums[0]

        for i in range(1, len(nums)):
            current_sum = max(nums[i], current_sum + nums[i])
            max_sum = max(max_sum, current_sum)

        return max_sum

def main():
    nums = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
    sol = Solution()
    result = sol.maxSubArray(nums)
    print(f"Maximum subarray sum is: {result}")

if __name__ == "__main__":
    main()
# Out:
# Maximum subarray sum is: 6

# %%
class solution:
  def finalPrices(self, prices: List[int]) -> List[int]:
    stack =[]
    result = prices[:]

    for i in range (len(prices)):
      while stack and prices[i] <= prices[stack[-1]]:
        idx = stack.po

# %%
from typing import List

class Solution:
    def finalPrices(self, prices: List[int]) -> List[int]:
        stack = []
        result = prices[:]  # copy of prices to store final prices

        for i in range(len(prices)):
            # While current price is less than or equal to price at top of stack
            while stack and prices[i] <= prices[stack[-1]]:
                idx = stack.pop()
                result[idx] = prices[idx] - prices[i]  # apply discount
            stack.append(i)

        return result

# %%
def maximum_sub_array(a):
  sum = 0
  maxsum = 0
  for i in range(0, len(a)):
    for j in range(i, len(a)):
      sum = sum +a[j]
      maxsum = max(sum, maxsum)
  return maxsum
